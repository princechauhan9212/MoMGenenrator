# %% [markdown]
# ### OCR (Optical character recognition )
# This OCR app will be used to extract text from an image of jandwritten notes
#
# Take the image (Handwritten Notes )--> Process the image (Computer vision)-->LLM(Role assigned as OCR)

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.13.0.90-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 1.9 MB/s eta 0:00:21
#     --------------------------------------- 0.8/40.2 MB 1.9 MB/s eta 0:00:21
#    - -------------------------------------- 1.0/40.2 MB 1.5 MB/s eta 0:00:26
#    - -------------------------------------- 1.6/40.2 MB 1.5 MB/s eta 0:00:26
#    -- ------------------------------------- 2.1/40.2 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.4/40.2 MB 1.8 MB/s eta 0:00:22
#    -- ------------------------------------- 2.9/40.2 MB 1.9 MB/s eta 0:00:21
#    --- ------------------------------------ 3.4/40.2 MB 1.9 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.2/40.2 MB 2.1 MB/s eta 0:00:18
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import google.generativeai as genai
import os
import PIL
from PIL import Image

# %%
image = cv2.imread('C:\github projects\GenAI\Projects\MoMGenenrator\Handwritten_notes.png') 
 # right now is BGR Image (Need to converted to RGB)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB) # BGR--> RGB
image_gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
_,image_bw = cv2.threshold(image_gray,150,255,cv2.THRESH_BINARY)

# %%
# So its a color image (3D)
image_grey.shape
# Out:
# (1152, 1308)

# %%
plt.imshow(image_grey)
plt.show()

# %%
cv2.imshow('Grey Image',image_gray)
cv2.imshow('B&W Image',image_bw)
cv2.imshow('Color',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# The image that Cv2 image has given is numpy array format , we need to convert it to image object
final_image = Image.fromarray(image_bw)

# %%
def image_converter(path):
    image = cv2.imread(path)
    image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    _,image_bw = cv2.threshold(image_gray,170,255,cv2.THRESH_BINARY)   
    return image_bw

# %%
# configrue LLM
gemini_key = os.getenv('Google_API_Key2')
genai.configure(api_key=gemini_key)
model = genai.GenerativeModel('gemini-2.5-flash-lite',
                               generation_config={'temperature':0.5})

# %%
prompt =''' 
<Role> Yoir are an OCR (Optical character recognition) application.
<Goal> Identify the characters in handwritten notes.
<Context> user has provided the image of handwritten notes.
<Instructions>
* Do not generate any new content 
* make sure that all the words from english language
* you can complete a word which is not recognized
* output should be well formated
'''

# %%
response = model.generate_content([prompt,final_image])
print(response.text)
# Out:
# -> Unsupervised Learning &
#
# - Clustering:- Grouping the data on the basis of
# high similarity of features such that the data points
# within the cluster have high similarity & cluster
# are dissimilar as much as possible.
#
# - That means for a good cluster, the dist btw the
# data points within the cluster must be small &
# distance btw the cluster must be larger.
#
# Types of clustering:
# (1) Centroid based - K-mean cluster
# (2) Hierarchical - Agglomeration
# (3) Density based - DBSCAN
# (Density Based Spatial Clustering of Applications)
#
# Centroid based clustering - K-mean clustering, to
# get centroid we take mean of $x_1 \& x_2$ (separately) to
# find K = elbow method
#
# Step 1 - Find K many method

# %% [markdown]
# ### Extracing text from word

# %%
pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
file = Document('C:\github projects\GenAI\Projects\MoMGenenrator\doc.docx')
doc_text = ''

# %%
for p in file.paragraphs:
    doc_text = doc_text +p.text +'\n'
print(doc_text)
# Out:
# Artificial Intelligence (AI) is the simulation of human intelligence in machines, enabling them to learn, reason, solve problems, perceive, and make decisions, often by analyzing vast amounts of data to recognize patterns and perform tasks without explicit programming for every scenario. It's a field of computer science focused on creating systems that mimic human cognitive functions, powering everyday applications like voice assistants (Siri, Alexa) and complex systems like self-driving cars.
# Core Concepts
# Learning: Acquiring information and rules for using information.
# Reasoning: Using rules to reach approximate or definite conclusions.
# Problem-Solving: Finding solutions to complex issues.
# Perception: Understanding the world through sensory input (e.g., computer vision).
# Language Understanding: Processing and responding to human language (Natural Language Processing).
# How it Works (Simplified)
# ...

# %% [markdown]
# | File Type   | Extension        | MIME Type                                                                 |
# | ----------- | ---------------- | ------------------------------------------------------------------------- |
# | Plain text  | `.txt`           | `text/plain`                                                              |
# | HTML        | `.html`          | `text/html`                                                               |
# | CSV         | `.csv`           | `text/csv`                                                                |
# | JSON        | `.json`          | `application/json`                                                        |
# | PDF         | `.pdf`           | `application/pdf`                                                         |
# | ZIP         | `.zip`           | `application/zip`                                                         |
# | JPEG image  | `.jpg` / `.jpeg` | `image/jpeg`                                                              |
# | PNG image   | `.png`           | `image/png`                                                               |
# | GIF         | `.gif`           | `image/gif`                                                               |
# | MP3 audio   | `.mp3`           | `audio/mpeg`                                                              |
# | MP4 video   | `.mp4`           | `video/mp4`                                                               |
# | Excel       | `.xls`           | `application/vnd.ms-excel`                                                |
# | Excel (new) | `.xlsx`          | `application/vnd.openxmlformats-officedocument.spreadsheetml.sheet`       |
# | Word        | `.doc`           | `application/msword`                                                      |
# | Word (new)  | `.docx`          | `application/vnd.openxmlformats-officedocument.wordprocessingml.document` |
